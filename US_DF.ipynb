# %%
# Questions:
# How does weather condition affect accidents? 	
# 	Count & Avg Sev by Weather Condition
# 	Count & Avg Sev by Time zone (4)
# 	Count & Avg Sev by State
# 	Count & Avg Sev by Month	
# 	Count & Avg Sev by Day of Week
# 	Count & Avg Sev by Time of the Day
# *** Optional:
# 	Count by Reason(s) for the accident (multiple columns per reason - group by each boolean column)
# 	Compare long weekend accidents (avg) with non-holiday weekends
# Basic Structure:
# # Read input data
# Read CSV (Sample)
# 	Create a DF
# 	Analyze DF for NULLs etc
# 	Clean DF -> Cleaned DF
# 	# Analyze & Chart the data
# 	Call Function - Analyze by Weather condition (DF as input)
# 	Call Function - Analyze by State (DF as input)
# 	Call Function - Analyze by Time zone (DF as input)
# 	Call Function - Analyze by Month (DF as input)
# 	Call Function - Analyze by Day of the week (DF as input)
# 	Call Function - Analyze by Time of the day (DF as input)

# %%
import csv
import os 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
panda_data_df = pd.read_csv("US_Accidents_May19.csv")
panda_data_df.head()
# Out:
#     ID    Source    TMC  Severity           Start_Time             End_Time  \
# 0  A-1  MapQuest  201.0         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  MapQuest  201.0         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  MapQuest  201.0         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  MapQuest  201.0         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  MapQuest  201.0         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  ...  Roundabout Station   Stop  \
# 0  39.865147 -84.058723      NaN      NaN  ...       False   False  False
# 1  39.928059 -82.831184      NaN      NaN  ...       False   False  False
# 2  39.063148 -84.032608      NaN      NaN  ...       False   False  False
# 3  39.747753 -84.205582      NaN      NaN  ...       False   False  False
# 4  39.627781 -84.188354      NaN      NaN  ...       False   False  False
#
#   Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset Civil_Twilight  \
# 0           False          False        False          Night          Night
# 1           False          False        False          Night          Night
# 2           False           True        False          Night          Night
# 3           False          False        False          Night            Day
# 4           False           True        False            Day            Day
#
#   Nautical_Twilight Astronomical_Twilight
# 0             Night                 Night
# 1             Night                   Day
# 2               Day                   Day
# 3               Day                   Day
# 4               Day                   Day
#
# [5 rows x 49 columns]

# %%
print(panda_data_df.shape)
print(panda_data_df.columns)
# Out:
# (2243939, 49)
# Index(['ID', 'Source', 'TMC', 'Severity', 'Start_Time', 'End_Time',
#        'Start_Lat', 'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)',
#        'Description', 'Number', 'Street', 'Side', 'City', 'County', 'State',
#        'Zipcode', 'Country', 'Timezone', 'Airport_Code', 'Weather_Timestamp',
#        'Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)',
#        'Visibility(mi)', 'Wind_Direction', 'Wind_Speed(mph)',
#        'Precipitation(in)', 'Weather_Condition', 'Amenity', 'Bump', 'Crossing',
#        'Give_Way', 'Junction', 'No_Exit', 'Railway', 'Roundabout', 'Station',
#        'Stop', 'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop',
#        'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
weather_state_co = panda_data_df[['Severity','Description', 'City','State', 'Timezone', 'Airport_Code', 'Weather_Condition']]
weather_state_co.head(10)
# Out:
#    Severity                                        Description          City  \
# 0         3  Right lane blocked due to accident on I-70 Eas...        Dayton
# 1         2  Accident on Brice Rd at Tussing Rd. Expect del...  Reynoldsburg
# 2         2  Accident on OH-32 State Route 32 Westbound at ...  Williamsburg
# 3         3  Accident on I-75 Southbound at Exits 52 52B US...        Dayton
# 4         2  Accident on McEwen Rd at OH-725 Miamisburg Cen...        Dayton
# 5         3  Accident on I-270 Outerbelt Northbound near Ex...   Westerville
# 6         2  Accident on Oakridge Dr at Woodward Ave. Expec...        Dayton
# 7         3  Accident on I-75 Southbound at Exit 54B Grand ...        Dayton
# 8         2  Accident on Notre Dame Ave at Warner Ave. Expe...        Dayton
# 9         3  Right hand shoulder blocked due to accident on...   Westerville
#
#   State    Timezone Airport_Code Weather_Condition
# 0    OH  US/Eastern         KFFO        Light Rain
# 1    OH  US/Eastern         KCMH        Light Rain
# 2    OH  US/Eastern         KI69          Overcast
# 3    OH  US/Eastern         KDAY     Mostly Cloudy
# 4    OH  US/Eastern         KMGY     Mostly Cloudy
# 5    OH  US/Eastern         KCMH        Light Rain
# 6    OH  US/Eastern         KDAY          Overcast
# 7    OH  US/Eastern         KDAY          Overcast
# 8    OH  US/Eastern         KFFO     Mostly Cloudy
# 9    OH  US/Eastern         KCMH        Light Rain

# %%
weather_conditions_df = weather_state_co.groupby(['Weather_Condition','State'])
weather_conditions_df
count_state = weather_conditions_df ["State"].count()
count_state.head()
final_df = pd.DataFrame({"Number of Accidents by State": count_state})
final_df.head()
# Out:
#                          Number of Accidents by State
# Weather_Condition State
# Blowing Sand      CA                                1
# Blowing Snow      CO                               20
#                   IA                                8
#                   ID                                2
#                   IL                                9

# %%
#maybe use this code to count by state that look better
count_by_state = weather_state_co.groupby('Weather_Condition')['State'].count()
final2_df = pd.DataFrame({'Number of Accidents ':count_by_state})
final2_df.head(60)
high_value_df = final2_df.drop(['Blowing Sand','Dust Whirls','Funnel Cloud', 'Hail', 'Heavy Blowing Snow', 'Heavy Freezing Drizzle', 'Heavy Freezing Rain','Heavy Ice Pellets','Heavy Rain Showers', 'Heavy Smoke', 'Heavy Thunderstorms and Snow', 'Heavy Thunderstorms with Small Hail', 'Light Blowing Snow', 'Light Fog', 'Light Hail', 'Light Haze', 'Light Snow Grains', 'Light Snow Showers', 'Light Thunderstorm', 'Light Thunderstorms and Snow', 'Low Drifting Snow', 'Sand', 'Small Hail', 'Snow Grains', 'Snow Showers', 'Squalls', 'Thunderstorms and Snow', 'Volcanic Ash'])
high_value_df
# Out:
#                               Number of Accidents
# Weather_Condition
# Blowing Snow                                   264
# Clear                                       808182
# Drizzle                                       1601
# Fog                                          11617
# Haze                                         27727
# Heavy Drizzle                                  199
# Heavy Rain                                    8929
# Heavy Snow                                    1149
# Heavy Thunderstorms and Rain                  2484
# Ice Pellets                                    101
# Light Drizzle                                 8058
# Light Freezing Drizzle                         777
# Light Freezing Fog                            1001
# Light Freezing Rain                           1997
# Light Ice Pellets                              262
# Light Rain                                  107164
# Light Rain Showers                             157
# Light Snow                                   36038
# Light Thunderstorms and Rain                  4928
# Mist                                          1918
# Mostly Cloudy                               310086
# Overcast                                    382482
# Partly Cloudy                               208371
# Patches of Fog                                1878
# Rain                                         24824
# Rain Showers                                   123
# Scattered Clouds                            204654
# Shallow Fog                                    841
# Smoke                                         3010
# Snow                                          4099
# Thunderstorm                                  4439
# Thunderstorms and Rain                        2215
# Widespread Dust                                129

# %%
highvalue_chart = high_value_df.plot(kind='bar')

# %%
# Severity and count of acccidents
Severity_by_state = weather_state_co.groupby('Severity')['State'].count()
Severity_by_state
final_sev_df = pd.DataFrame({'Number of Accidents': Severity_by_state})
final_sev_df
# Out:
#           Number of Accidents
# Severity
# 0                          17
# 1                         814
# 2                     1455524
# 3                      715582
# 4                       72002

# %%
av_severity = weather_state_co.groupby('State')['Severity'].mean()
av_severity
state_severity = pd.DataFrame({'Severity Average by State': av_severity})
state_severity
# Out:
#        Severity Average by State
# State
# AL                      2.415175
# AR                      2.884200
# AZ                      2.316878
# CA                      2.393750
# CO                      2.511629
# CT                      2.605784
# DC                      2.494527
# DE                      2.410371
# FL                      2.382129
# GA                      2.672704
# IA                      2.618402
# ID                      2.321006
# IL                      2.334361
# IN                      2.435850
# KS                      2.559242
# KY                      2.589757
# LA                      2.221666
# MA                      2.402820
# MD                      2.666793
# ME                      2.126582
# MI                      2.462084
# MN                      2.530350
# MO                      2.607713
# MS                      2.509158
# MT                      2.695853
# NC                      2.159986
# ND                      2.702703
# NE                      2.167581
# NH                      2.215448
# NJ                      2.390646
# NM                      2.478529
# NV                      2.425633
# NY                      2.469073
# OH                      2.499111
# OK                      2.110273
# OR                      2.203101
# PA                      2.297373
# RI                      2.542179
# SC                      2.243218
# SD                      3.113636
# TN                      2.381405
# TX                      2.292968
# UT                      2.411253
# VA                      2.536678
# VT                      2.368421
# WA                      2.410361
# WI                      2.670444
# WV                      2.613532
# WY                      3.109589
